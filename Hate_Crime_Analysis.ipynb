# %%
# Import necessary modules
import pandas as pd
import numpy as np
import math
import statistics
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt



fbi_crime = "hate_crime.csv"
hate_crime_df = pd.read_csv(fbi_crime, low_memory=False)

# %%
# View data frame
hate_crime_df.head()
# Out:
#    INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0         3015       1991  AR0040200          Rogers             NaN
# 1         3016       1991  AR0290100            Hope             NaN
# 2           43       1991  AR0350100      Pine Bluff             NaN
# 3           44       1991  AR0350100      Pine Bluff             NaN
# 4         3017       1991  AR0350100      Pine Bluff             NaN
#
#   AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME REGION_NAME  ...  \
# 0             City         AR   Arkansas  West South Central       South  ...
# 1             City         AR   Arkansas  West South Central       South  ...
# 2             City         AR   Arkansas  West South Central       South  ...
# 3             City         AR   Arkansas  West South Central       South  ...
# 4             City         AR   Arkansas  West South Central       South  ...
#
#                OFFENDER_RACE OFFENDER_ETHNICITY VICTIM_COUNT  \
# 0                      White                NaN            1
# 1  Black or African American                NaN            1
# 2  Black or African American                NaN            1
# 3  Black or African American                NaN            2
# 4  Black or African American                NaN            1
#
#                                         OFFENSE_NAME  \
# 0                                       Intimidation
# 1                                     Simple Assault
# 2                                 Aggravated Assault
# 3  Aggravated Assault;Destruction/Damage/Vandalis...
# 4                                 Aggravated Assault
#
#    TOTAL_INDIVIDUAL_VICTIMS                       LOCATION_NAME  \
# 0                       1.0  Highway/Road/Alley/Street/Sidewalk
# 1                       1.0  Highway/Road/Alley/Street/Sidewalk
# 2                       1.0                      Residence/Home
# 3                       1.0  Highway/Road/Alley/Street/Sidewalk
# 4                       1.0                 Service/Gas Station
#
#                         BIAS_DESC  VICTIM_TYPES MULTIPLE_OFFENSE MULTIPLE_BIAS
# 0  Anti-Black or African American    Individual                S             S
# 1                      Anti-White    Individual                S             S
# 2  Anti-Black or African American    Individual                S             S
# 3                      Anti-White    Individual                M             S
# 4                      Anti-White    Individual                S             S
#
# [5 rows x 28 columns]

# %%
# Describe the numeric variables in the data set
hate_crime_df.describe()
# Out:
#         INCIDENT_ID      DATA_YEAR  ADULT_VICTIM_COUNT  JUVENILE_VICTIM_COUNT  \
# count  2.195770e+05  219577.000000        51411.000000           49539.000000
# mean   2.080389e+05    2005.472691            0.658867               0.085327
# std    3.251394e+05       8.591466            1.238581               0.513304
# min    2.000000e+00    1991.000000            0.000000               0.000000
# 25%    5.489600e+04    1998.000000            0.000000               0.000000
# 50%    1.097900e+05    2005.000000            1.000000               0.000000
# 75%    1.646850e+05    2013.000000            1.000000               0.000000
# max    1.358628e+06    2020.000000          146.000000              60.000000
#
#        TOTAL_OFFENDER_COUNT  ADULT_OFFENDER_COUNT  JUVENILE_OFFENDER_COUNT  \
# count         219577.000000          47130.000000             47123.000000
# mean               0.955724              0.548207                 0.099081
# std                1.358364              0.844695                 0.482898
# min                0.000000              0.000000                 0.000000
# 25%                0.000000              0.000000                 0.000000
# 50%                1.000000              0.000000                 0.000000
# 75%                1.000000              1.000000                 0.000000
# max               99.000000             60.000000                20.000000
#
#         VICTIM_COUNT  TOTAL_INDIVIDUAL_VICTIMS
# count  219577.000000             216098.000000
# mean        1.247567                  0.984715
# std         2.274116                  1.173726
# min         1.000000                  0.000000
# 25%         1.000000                  1.000000
# 50%         1.000000                  1.000000
# 75%         1.000000                  1.000000
# max       900.000000                147.000000

# %%
print(hate_crime_df.columns)
# Out:
# Index(['INCIDENT_ID', 'DATA_YEAR', 'ORI', 'PUB_AGENCY_NAME', 'PUB_AGENCY_UNIT',
#        'AGENCY_TYPE_NAME', 'STATE_ABBR', 'STATE_NAME', 'DIVISION_NAME',
#        'REGION_NAME', 'POPULATION_GROUP_CODE', 'POPULATION_GROUP_DESC',
#        'INCIDENT_DATE', 'ADULT_VICTIM_COUNT', 'JUVENILE_VICTIM_COUNT',
#        'TOTAL_OFFENDER_COUNT', 'ADULT_OFFENDER_COUNT',
#        'JUVENILE_OFFENDER_COUNT', 'OFFENDER_RACE', 'OFFENDER_ETHNICITY',
#        'VICTIM_COUNT', 'OFFENSE_NAME', 'TOTAL_INDIVIDUAL_VICTIMS',
#        'LOCATION_NAME', 'BIAS_DESC', 'VICTIM_TYPES', 'MULTIPLE_OFFENSE',
#        'MULTIPLE_BIAS'],
#       dtype='object')

# %%
# Filter by year (2010 - 2020)
 #- Can also do by decade
# Group by region to see if some regions are different from others
# How many are multiple offenses vs single?
# Possibly get mean, std, and max for victim_count

# %%
# What regions do we have?
hate_crime_df['REGION_NAME'].unique()
# Out:
# array(['South', 'West', 'Northeast', 'Midwest', 'U.S. Territories',
#        'Other'], dtype=object)

# %%
# Group by race
hate_crime_df.groupby('OFFENDER_RACE').count()
# Out:
#                                            INCIDENT_ID  DATA_YEAR    ORI  \
# OFFENDER_RACE
# American Indian or Alaska Native                  1211       1211   1211
# Asian                                             1596       1596   1596
# Black or African American                        28507      28507  28507
# Multiple                                          4423       4423   4423
# Native Hawaiian or Other Pacific Islander           83         83     83
# Unknown                                          97334      97334  97334
# White                                            86403      86403  86403
#
#                                            PUB_AGENCY_NAME  PUB_AGENCY_UNIT  \
# OFFENDER_RACE
# American Indian or Alaska Native                      1211               19
# Asian                                                 1596               52
# Black or African American                            28507              448
# Multiple                                              4423               85
# Native Hawaiian or Other Pacific Islander               83                3
# Unknown                                              97334             3878
# White                                                86403             1945
#
#                                            AGENCY_TYPE_NAME  STATE_ABBR  \
# OFFENDER_RACE
# American Indian or Alaska Native                       1211        1211
# Asian                                                  1596        1596
# Black or African American                             28507       28507
# Multiple                                               4423        4423
# Native Hawaiian or Other Pacific Islander                83          83
# Unknown                                               97334       97334
# White                                                 86403       86403
#
#                                            STATE_NAME  DIVISION_NAME  \
# OFFENDER_RACE
# American Indian or Alaska Native                 1211           1211
# Asian                                            1596           1596
# Black or African American                       28507          28507
# Multiple                                         4423           4423
# Native Hawaiian or Other Pacific Islander          83             83
# Unknown                                         97334          97334
# White                                           86403          86403
#
#                                            REGION_NAME  ...  \
# OFFENDER_RACE                                           ...
# American Indian or Alaska Native                  1211  ...
# Asian                                             1596  ...
# Black or African American                        28507  ...
# Multiple                                          4423  ...
# Native Hawaiian or Other Pacific Islander           83  ...
# Unknown                                          97334  ...
# White                                            86403  ...
#
#                                            JUVENILE_OFFENDER_COUNT  \
# OFFENDER_RACE
# American Indian or Alaska Native                               365
# Asian                                                          385
# Black or African American                                     8039
# Multiple                                                      1324
# Native Hawaiian or Other Pacific Islander                       79
# Unknown                                                      15844
# White                                                        21067
#
#                                            OFFENDER_ETHNICITY  VICTIM_COUNT  \
# OFFENDER_RACE
# American Indian or Alaska Native                          245          1211
# Asian                                                     243          1596
# Black or African American                                5277         28507
# Multiple                                                  874          4423
# Native Hawaiian or Other Pacific Islander                  67            83
# Unknown                                                 14658         97334
# White                                                   13492         86403
#
#                                            OFFENSE_NAME  \
# OFFENDER_RACE
# American Indian or Alaska Native                   1211
# Asian                                              1596
# Black or African American                         28507
# Multiple                                           4423
# Native Hawaiian or Other Pacific Islander            83
# Unknown                                           97334
# White                                             86403
#
#                                            TOTAL_INDIVIDUAL_VICTIMS  \
# OFFENDER_RACE
# American Indian or Alaska Native                               1208
# Asian                                                          1582
# Black or African American                                     28421
# Multiple                                                       4367
# Native Hawaiian or Other Pacific Islander                        78
# Unknown                                                       94370
# White                                                         86052
#
#                                            LOCATION_NAME  BIAS_DESC  \
# OFFENDER_RACE
# American Indian or Alaska Native                    1211       1211
# Asian                                               1596       1596
# Black or African American                          28507      28507
# Multiple                                            4423       4423
# Native Hawaiian or Other Pacific Islander             83         83
# Unknown                                            97334      97334
# White                                              86403      86403
#
#                                            VICTIM_TYPES  MULTIPLE_OFFENSE  \
# OFFENDER_RACE
# American Indian or Alaska Native                   1211              1211
# Asian                                              1596              1596
# Black or African American                         28507             28507
# Multiple                                           4423              4423
# Native Hawaiian or Other Pacific Islander            83                83
# Unknown                                           97334             97334
# White                                             86403             86403
#
#                                            MULTIPLE_BIAS
# OFFENDER_RACE
# American Indian or Alaska Native                    1211
# Asian                                               1596
# Black or African American                          28507
# Multiple                                            4423
# Native Hawaiian or Other Pacific Islander             83
# Unknown                                            97334
# White                                              86403
#
# [7 rows x 27 columns]
